# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# # initialize data of lists.
# data = {'bussiness name': ["b1", 'b2', ],
#         'Dog Care / Dogsitting': [True, False, ],
#         'GROOMING': [True, False, ],
#         'Training': [True, False, ],
#         'WALKING SERVICE': [True, False, ],
#         }
  
# df = pd.DataFrame(data, )
# # df = pd.DataFrame(data, index=[])
# df
# Out:
#   bussiness name  Dog Care / Dogsitting  GROOMING  Training  WALKING SERVICE
# 0             b1                   True      True      True             True
# 1             b2                  False     False     False            False

# %%
df = pd.read_csv("dog bussiness thing - Sheet1.csv")
df
# Out:
#            bussiness name  Dog Care / Dogsitting  Grooming  Training
# 0            mydogcompany                    1.0       NaN       NaN  \
# 1                citydogs                    1.0       1.0       1.0
# 2               dogaffair                    1.0       1.0       1.0
# 3                 dog2dog                    1.0       1.0       NaN
# 4   hundeschule-glattpark                    1.0       NaN       NaN
# 5                pawhouse                    1.0       1.0       1.0
# 6      hundeabenteuerland                    1.0       NaN       NaN
# 7            walking-dogs                    1.0       NaN       NaN
# 8                fit-dogs                    1.0       NaN       NaN
# 9           maykesdogwalk                    1.0       NaN       NaN
# 10                citypet                    NaN       NaN       NaN
# 11        happy-hundehort                    1.0       NaN       NaN
# 12               woofwoof                    1.0       NaN       1.0
# ...

# %%
df = df.fillna(False)
df = df.replace(1.0,True)
df.shape
# Out:
# (24, 8)

# %%
# plt.plot( df['Dog Care / Dogsitting'].index, df['Dog Care / Dogsitting'].value_counts() )

cols = ['Dog Care / Dogsitting','Grooming','Training','Walking Service','Transport',]

for i, c  in enumerate(cols):
    # print(c,i )
    # print(c, df[df[c] == True].shape[0])
    active = df[df[c] == True].shape[0]
    plt.bar(i, active, label = c, edgecolor='black')

# plt.set_xticks=[cols]
# plt.xticks(np.arange(len(cols)), cols)

plt.legend()

# df[df['Grooming'] == True].shape
# # df[df['Grooming'] == True]
# df.columns

# plt.plot( df['Grooming'].index, df['Grooming'].value_counts() )
# plt.plot( df['Training'].index, df['Training'].value_counts() )
# plt.plot( df['Walking Service'].index, df['Walking Service'].value_counts() )
# plt.plot( df['Transport'].index, df['Transport'].value_counts() )
