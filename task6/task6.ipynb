# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("HousingData.csv")
# df = pd.read_csv("housing.csv",delim_whitespace=True)

# %%
# df.reset_index
# df.info()

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# 3. Create a bar plot to show the number of missing values in each column.
df.isnull().sum(axis = 0)
df.isna().sum()
plt.bar(df.columns, df.isnull().sum(axis = 0))
# Out:
# <BarContainer object of 14 artists>

# %%
from sklearn.impute import SimpleImputer

# 'mean', 'median', 'most_frequent', 'constant'

imputer = SimpleImputer(strategy='most_frequent')
imputer.fit(df)
imputed_data = imputer.transform(df)
# print(imputed_data)
pd.DataFrame(imputed_data, columns=df.columns)
# df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX
# 0    0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0  \
# 1    0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593   69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120   76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976   91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794   89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  100.0  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
# median strategy
imputer = SimpleImputer(strategy='median')
imputer.fit(df)
imputed_data = imputer.transform(df)
pd.DataFrame(imputed_data, columns=df.columns).head()
# df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  \
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90  11.43  36.2

# %%
# constant strategy
imputer = SimpleImputer(strategy='constant', fill_value=0)
imputer.fit(df)
imputed_data = imputer.transform(df)
pd.DataFrame(imputed_data, columns=df.columns).head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  \
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   0.00  36.2

# %%
# mean strategy
imputer = SimpleImputer(strategy='mean')
imputer.fit(df)
imputed_data = imputer.transform(df)
pd.DataFrame(imputed_data, columns=df.columns).tail()
# df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD    TAX
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.100000  2.4786  1.0  273.0  \
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.700000  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.000000  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.300000  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  68.518519  2.5050  1.0  273.0
#
#      PTRATIO       B      LSTAT  MEDV
# 501     21.0  391.99  12.715432  22.4
# 502     21.0  396.90   9.080000  20.6
# 503     21.0  396.90   5.640000  23.9
# 504     21.0  393.45   6.480000  22.0
# 505     21.0  396.90   7.880000  11.9

# %%
X = df["CRIM"].to_numpy()
y = df["AGE"].to_numpy()

x1 = X[:]

print(f"X  {X.shape}")
print(f"x1 {x1.shape}")
print(f"Y  {y.shape}")

# for i in x1:
#     print(i)
# Out:
# X  (506,)
# x1 (506,)
# Y  (506,)

# %%
all_cols = df.columns
data = [df[i] for i in all_cols]

# print()
# for i in data:
#     print(i, type(i))
# print(len(data))
data = np.array(data)
print(data.shape, type(data))
# Out:
# (14, 506) <class 'numpy.ndarray'>

# %%
from reparo import CDI
CDI_method = CDI()
CDI_method.fit(data)
# Out:
# CDI()

# %%
from reparo import FRNNI
FRNNI_method = FRNNI()

# %%
from reparo import HotDeckImputation
HotDeckImputation_method = HotDeckImputation()

# %%
from reparo import KNNImputer
KNNImputer_method = KNNImputer()

# %%
from reparo import PMM
PMM_method = PMM()

# %%
from reparo import SICE
SICE_method = SICE()

# %%
from reparo import MICE
MICE_method = MICE()

# %%
# CDI
CDI_method.fit(data)
CDI_X_transformed = CDI_method.transform(data)

# %%
# FRNNI
FRNNI_method.fit(data)
FRNNI_method_X_transformed = FRNNI_method.transform(data)

# %%
# HotDeckImputation
HotDeckImputation_method.fit(data)
FRNNI_method_X_transformed = HotDeckImputation_method.transform(data)

# %%
# KNNImputer
KNNImputer_method.fit(data)
X_transformed = KNNImputer_method.transform(data)

# print(f"data {type(data)}")
# print(f"data {data}")

# ===================
# KNNImputer_method.fit(X, y)
# X.shape
# X_transformed = KNNImputer_method.transform(X,y)

# X_transformed = KNNImputer_method.fit_transform(X)

# df2 = KNNImputer_method.apply(df, ["CRIM","AGE"])
# print(df2)
# df["AGE"].isna().sum()

# X_transformed = KNNImputer_method.fit_transform(X)

# # KNNImputer_method.fit( KNNImputer_method.fit(df["TAX"], df["MEDV"]) )
# # X_transformed = KNNImputer_method.transfo  rm(df["TAX"])
# # X_transformed = KNNImputer_method.fit_transform(df["TAX"])
# # df[["TAX","MEDV"]]

# %%
# PMM
PMM_method.fit(data)
PMM_X_transformed = PMM_method.transform(data)

# %%
# SICE
SICE_method.fit(data)
data

print(data.shape)
print(x1.shape)

# np.where(pd.isnull(data))
print( np.count_nonzero(np.isnan(x1)) )
print( np.where(pd.isnull(x1))[0] )

# missing_values = np.where(pd.isnull(data))
# print(missing_values[0])
# print(missing_values[1])

# missing_values = list(zip(missing_values[0], missing_values[1]))

# SICE_X_transformed = SICE_method.fit_transform(data, x1)
# SICE_X_transformed = SICE_method.transform(data)
# Out:
# (14, 506)
# (506,)
# 20
# [ 53 115 183 191 192 196 229 236 241 262 288 302 369 393 394 409 426 430
#  460 465]

# %%
# MICE
print( np.count_nonzero(np.isnan(X)) )
MICE_method.fit(X)
# MICE_X_transformed = MICE_method.transform(X)
# Out:
# 20
# MICE()

# %%
df2 = df[:]
# print(df2 is df)
print( df["CRIM"].isna().sum() )
print( df["LSTAT"].isna().sum() )
CDI_method.apply(df2, ["CRIM","LSTAT"])
# FRNNI_method.apply(df2, ["CRIM","LSTAT"])
# HotDeckImputation_method.apply(df2, ["CRIM","LSTAT"])
# KNNImputer_method.apply(df2, ["CRIM","LSTAT"])
# PMM_method.apply(df2, ["CRIM","AGE"]) # not working, not finding columns in df
# SICE_method.apply(df2, ["CRIM","LSTAT"])
print( df["CRIM"].isna().sum() )
print( df["LSTAT"].isna().sum() )
df2
